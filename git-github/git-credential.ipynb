# %% [markdown]
# # 자격 증명 관리
# ## 윈도우
# <span style="color:blue;background-color:white;border-bottom:1px dotted #505050;font-size:18px;font-weight:bold;"> `git config --system credential.helper` 윈도우 자격증명(credential) 관리 - credential.helper 값이 manager이면 Git은 윈도우 운영체제에서 제공하는 자격증명관리자에 사용자 인증 관련 정보를 저장<br>
# [시작] -> [검색창]에 "자격" 입력 후 "자격 증명 관리자"실행<br>![image.png](attachment:04121fef-b7c7-4198-ad27-d423b8f47d38.png)<br>
# </span>
